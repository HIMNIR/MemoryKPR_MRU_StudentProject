# %%
import torch
from PIL import Image
import os
from ultralytics import YOLO
import pandas as pd

# %%
model = torch.hub.load('ultralytics/yolov8', 'custom', path='yolov8s.pt', force_reload=True)
images_directory = 'Example Data-20240208T214429Z-001/Example Data/exported'
images = os.listdir(images_directory)

# Prepare a list to hold the results
detection_results = []

# Iterate over the images and perform object detection
for image_name in images:
    # Construct the full image path
    image_path = os.path.join(images_directory, image_name)
    
    # Load the image
    img = Image.open(image_path)
    
    # Perform detection
    results = model(img, size=640)
    
    # Extract detected object names
    detected_objects = results.names[results.pred[0][:, -1].int()]
    
    # Save or process the detection results as needed
    # For example, append the detected objects and the image name to the detection_results list
    detection_results.append((image_name, detected_objects))

# Example: Print the detection results
for result in detection_results:
    print(f"Image: {result[0]}, Detected Objects: {result[1]}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model = torch.hub.load('ultralytics/yolov8', 'custom', path='yolov8s.pt', force_reload=True)
#       2 images_directory = 'Example Data-20240208T214429Z-001/Example Data/exported'
#       3 images = os.listdir(images_directory)
#
# File c:\Python312\Lib\site-packages\torch\hub.py:563, in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     559     raise ValueError(
#     560         f'Unknown source: "{source}". Allowed values: "github" | "local".')
#     562 if source == 'github':
# --> 563     repo_or_dir = _get_cache_or_reload(repo_or_dir, force_reload, trust_repo, "load",
#     564                                        verbose=verbose, skip_validation=skip_validation)
#     566 model = _load_local(repo_or_dir, model, *args, **kwargs)
# ...

# %%
# Load the Excel file
excel_path = 'Example Data-20240208T214429Z-001/Example Data/ImageLabels.xlsx'
df = pd.read_excel(excel_path)

# Display the first few rows of the dataframe to understand its structure
df.head()
# Out:
#                                    Image Name          Categories  Confidence  \
# 0  (1) @GreyCupFestival - 109th Grey Cup.jpeg  Person Description   99.835724
# 1  (1) @GreyCupFestival - 109th Grey Cup.jpeg  Person Description   99.835724
# 2  (1) @GreyCupFestival - 109th Grey Cup.jpeg  Person Description   99.835724
# 3  (1) @GreyCupFestival - 109th Grey Cup.jpeg  Person Description   99.835724
# 4  (1) @GreyCupFestival - 109th Grey Cup.jpeg  Person Description   99.316856
#
#   Aliases                Parents  Instance Count  Unnamed: 6   Label
# 0     NaN                 Person               2         NaN   Adult
# 1     NaN                 Person               1         NaN  Female
# 2   Human                    NaN               7         NaN  Person
# 3     NaN  Adult, Female, Person               1         NaN   Woman
# 4     NaN                 Person               1         NaN    Male
